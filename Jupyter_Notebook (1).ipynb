# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Sumohi Kiran**
# <br>Data scientist

# %% [markdown]
# *I am interested in data science because there are huge amount of data available, which a one can use it for many benefits. This field is broadest with numerous opportunity and the plus point is one cannot have to be from specific subject background, anyone can become data scientist. All one need is to 'be curious about data'.*

# %% [markdown]
# <h3>The following code will display 'hello world'

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# ---

# %% [markdown]
# ![20201121_234217.jpg](attachment:1aac810f-818e-4599-b9ae-8f182ff92d9e.jpg)

# %% [markdown]
# ---

# %% [markdown]
# - His name is pupu
# - He is my pet squirrel
# - I rescue him
